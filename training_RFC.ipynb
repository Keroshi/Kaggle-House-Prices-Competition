# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_log_error

# %%
# %store -r df
df
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0       0.073375         3    -0.250214 -0.207142       1      0         3
# 1      -0.872563         3     0.381508 -0.091886       1      0         3
# 2       0.073375         3    -0.123869  0.073480       1      0         0
# 3       0.309859         3    -0.460788 -0.096897       1      0         0
# 4       0.073375         3     0.549967  0.375148       1      0         0
# ...          ...       ...          ...       ...     ...    ...       ...
# 1455    0.073375         3    -0.376558 -0.260560       1      0         3
# 1456   -0.872563         3     0.592082  0.266407       1      0         3
# 1457    0.309859         3    -0.208099 -0.147810       1      0         3
# 1458   -0.872563         3    -0.123869 -0.080160       1      0         3
# 1459   -0.872563         3     0.170934 -0.058112       1      0         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0               3          0          4  ... -0.068692       2      2
# 1               3          0          2  ... -0.068692       2      2
# 2               3          0          4  ... -0.068692       2      2
# 3               3          0          0  ... -0.068692       2      2
# 4               3          0          2  ... -0.068692       2      2
# ...           ...        ...        ...  ...       ...     ...    ...
# 1455            3          0          4  ... -0.068692       2      2
# 1456            3          0          4  ... -0.068692       2      2
# 1457            3          0          4  ... -0.068692       2      0
# 1458            3          0          4  ... -0.068692       2      2
# 1459            3          0          4  ... -0.068692       2      2
#
#       MiscFeature   MiscVal    MoSold    YrSold  SaleType  SaleCondition  \
# 0               2 -0.087688 -1.599111  0.138777         8              4
# 1               2 -0.087688 -0.489110 -0.614439         8              4
# 2               2 -0.087688  0.990891  0.138777         8              4
# 3               2 -0.087688 -1.599111 -1.367655         8              0
# 4               2 -0.087688  2.100892  0.138777         8              4
# ...           ...       ...       ...       ...       ...            ...
# 1455            2 -0.087688  0.620891 -0.614439         8              4
# 1456            2 -0.087688 -1.599111  1.645210         8              4
# 1457            2  4.953112 -0.489110  1.645210         8              4
# 1458            2 -0.087688 -0.859110  1.645210         8              4
# 1459            2 -0.087688 -0.119110  0.138777         8              4
#
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 80 columns]

# %%
target = df["SalePrice"]
train_df = df.drop("SalePrice", axis=1)
train_df
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0       0.073375         3    -0.250214 -0.207142       1      0         3
# 1      -0.872563         3     0.381508 -0.091886       1      0         3
# 2       0.073375         3    -0.123869  0.073480       1      0         0
# 3       0.309859         3    -0.460788 -0.096897       1      0         0
# 4       0.073375         3     0.549967  0.375148       1      0         0
# ...          ...       ...          ...       ...     ...    ...       ...
# 1455    0.073375         3    -0.376558 -0.260560       1      0         3
# 1456   -0.872563         3     0.592082  0.266407       1      0         3
# 1457    0.309859         3    -0.208099 -0.147810       1      0         3
# 1458   -0.872563         3    -0.123869 -0.080160       1      0         3
# 1459   -0.872563         3     0.170934 -0.058112       1      0         3
#
#       LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# 0               3          0          4  ...    -0.270208 -0.068692       2
# 1               3          0          2  ...    -0.270208 -0.068692       2
# 2               3          0          4  ...    -0.270208 -0.068692       2
# 3               3          0          0  ...    -0.270208 -0.068692       2
# 4               3          0          2  ...    -0.270208 -0.068692       2
# ...           ...        ...        ...  ...          ...       ...     ...
# 1455            3          0          4  ...    -0.270208 -0.068692       2
# 1456            3          0          4  ...    -0.270208 -0.068692       2
# 1457            3          0          4  ...    -0.270208 -0.068692       2
# 1458            3          0          4  ...    -0.270208 -0.068692       2
# 1459            3          0          4  ...    -0.270208 -0.068692       2
#
#       Fence  MiscFeature   MiscVal    MoSold    YrSold  SaleType  \
# 0         2            2 -0.087688 -1.599111  0.138777         8
# 1         2            2 -0.087688 -0.489110 -0.614439         8
# 2         2            2 -0.087688  0.990891  0.138777         8
# 3         2            2 -0.087688 -1.599111 -1.367655         8
# 4         2            2 -0.087688  2.100892  0.138777         8
# ...     ...          ...       ...       ...       ...       ...
# 1455      2            2 -0.087688  0.620891 -0.614439         8
# 1456      2            2 -0.087688 -1.599111  1.645210         8
# 1457      0            2  4.953112 -0.489110  1.645210         8
# 1458      2            2 -0.087688 -0.859110  1.645210         8
# 1459      2            2 -0.087688 -0.119110  0.138777         8
#
#       SaleCondition
# 0                 4
# 1                 4
# 2                 4
# 3                 0
# 4                 4
# ...             ...
# 1455              4
# 1456              4
# 1457              4
# 1458              4
# 1459              4
#
# [1460 rows x 79 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df, target, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
root_error = root_mean_squared_log_error(y_test, predictions)
print(root_error)
# Out:
# 0.15245549504092165

# %%
predictions
# Out:
# array([139754.  , 329043.87, 114470.5 , 163169.5 , 324644.79,  85205.83,
#        207872.2 , 151882.9 ,  85811.66, 126531.87, 155673.52, 121549.33,
#        109362.  , 206337.09, 178961.5 , 131858.  , 193130.8 , 135496.12,
#        114594.25, 207130.7 , 162734.  , 221862.97, 176874.9 , 127665.75,
#        194087.71, 174533.63, 185567.95, 109627.  , 177337.3 , 191320.84,
#        124455.88, 244940.07, 183553.91, 114368.5 , 256861.21, 145408.  ,
#        139364.  , 204301.7 , 313893.08, 110418.32, 127377.5 , 235796.16,
#        120515.33, 365965.63, 131520.  , 150519.84, 114244.83, 126905.83,
#        396574.05, 147249.68, 121619.  , 198891.48, 126143.9 , 362092.19,
#        139356.5 , 237015.8 , 197635.25, 150068.17, 145609.  , 113380.49,
#         78398.  , 147884.75, 305321.06, 280667.96, 287014.76, 208423.  ,
#        111127.  , 315294.11, 121201.75, 165574.04, 129591.25, 128904.41,
#        115015.5 ,  89838.5 , 454685.55, 172513.06, 315033.86, 292237.17,
#        138886.5 , 122050.83, 100798.  , 106264.5 , 126419.25, 105057.37,
